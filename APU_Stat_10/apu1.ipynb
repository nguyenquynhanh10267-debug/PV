# %%
import numpy as np;
import pandas as pd;
import matplotlib.pyplot as plt;
import seaborn as sns;

# %%
stats = pd.read_csv(r'D:\energy\PV\cleaned_data\apu_stat_10s.csv');
stats.head()
# Out:
#        Log Type System            TimeStamp    VL1N/V    VL2N/V    VL3N/V  \
# 0  APU Stat 10s  APU 1  2025-10-01 00:00:00  380.5441  382.1090  380.4408
# 1  APU Stat 10s  APU 1  2025-10-01 00:00:00  380.4019  382.1165  379.6272
# 2  APU Stat 10s  APU 1  2025-10-01 00:00:00  382.0461  380.7161  378.6526
# 3  APU Stat 10s  APU 1  2025-10-01 00:00:00  381.4481  382.7280  378.9417
# 4  APU Stat 10s  APU 1  2025-10-01 00:00:00  381.6455  381.0680  379.0313
#
#      VL12/V    VL23/V    VL31/V      f/Hz  ...     IL3/A  PL1/kW  PL2/kW  \
# 0  660.0041  658.0067  661.2325  50.22484  ...  0.437098     0.0     0.0
# 1  659.0755  657.1038  660.3568  50.19188  ...  0.402317     0.0     0.0
# 2  660.3620  659.9109  663.0081  50.16247  ...  0.453449     0.0     0.0
# 3  660.3810  658.4229  661.7881  50.20512  ...  0.452410     0.0     0.0
# 4  659.5617  657.6316  660.8498  50.20505  ...  0.410693     0.0     0.0
#
#    PL3/kW  QL1/kvar  QL2/kvar  QL3/kvar     Vdc/V     Idc/A    Pdc/kW
# ...

# %%
stats.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 963845 entries, 0 to 963844
# Data columns (total 22 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Log Type   963845 non-null  str
#  1   System     963845 non-null  str
#  2   TimeStamp  963845 non-null  str
#  3   VL1N/V     963845 non-null  float64
#  4   VL2N/V     963845 non-null  float64
#  5   VL3N/V     963845 non-null  float64
#  6   VL12/V     963845 non-null  float64
#  7   VL23/V     963845 non-null  float64
#  8   VL31/V     963845 non-null  float64
#  9   f/Hz       963845 non-null  float64
#  10  IL1/A      963845 non-null  float64
#  11  IL2/A      963845 non-null  float64
#  12  IL3/A      963845 non-null  float64
#  13  PL1/kW     963845 non-null  float64
#  14  PL2/kW     963845 non-null  float64
#  15  PL3/kW     963845 non-null  float64
#  16  QL1/kvar   963845 non-null  float64
#  17  QL2/kvar   963845 non-null  float64
#  18  QL3/kvar   963845 non-null  float64
# ...

# %%
stats.duplicated().sum()
# Out:
# np.int64(186)
