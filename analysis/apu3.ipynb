# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
stats = pd.read_csv(r'D:\energy\PV\analysis\APU_Stat_10s.csv');
stats.head()
# Out:
#        Log Type System           Time Stamp    VL1N/V    VL2N/V    VL3N/V  \
# 0  APU Stat 10s  APU 1  2026-01-12 00:00:00  375.1977  376.4349  373.0216
# 1  APU Stat 10s  APU 2  2026-01-12 00:00:00  375.1977  376.4349  373.0216
# 2  APU Stat 10s  APU 3  2026-01-12 00:00:00  376.5606  373.9651  372.8825
# 3  APU Stat 10s  APU 4  2026-01-12 00:00:00  376.5606  373.9651  372.8825
# 4  APU Stat 10s  APU 1  2026-01-12 00:01:00  375.1189  376.0260  372.9874
#
#      VL12/V    VL23/V    VL31/V     f/Hz  ...   IL3/A  PL1/kW  PL2/kW  PL3/kW  \
# 0  652.1350  648.5198  652.0514  49.8521  ...  0.5301     0.0     0.0     0.0
# 1  652.1350  648.5198  652.0514  49.8521  ...  0.4907     0.0     0.0     0.0
# 2  651.0746  649.1744  649.1862  49.8500  ...  0.4565     0.0     0.0     0.0
# 3  651.0746  649.1744  649.1862  49.8500  ...  0.5638     0.0     0.0     0.0
# 4  651.8266  647.7210  651.6465  49.8938  ...  0.5160     0.0     0.0     0.0
#
# ...

# %%
stats_apu3 = stats.loc[stats['System'] == 'APU 3']
stats_apu3.head()
# Out:
#         Log Type System           Time Stamp    VL1N/V    VL2N/V    VL3N/V  \
# 2   APU Stat 10s  APU 3  2026-01-12 00:00:00  376.5606  373.9651  372.8825
# 6   APU Stat 10s  APU 3  2026-01-12 00:01:00  376.4925  373.4681  372.7425
# 10  APU Stat 10s  APU 3  2026-01-12 00:02:00  376.0988  374.1064  372.8425
# 14  APU Stat 10s  APU 3  2026-01-12 00:03:00  376.8478  373.9523  373.3496
# 18  APU Stat 10s  APU 3  2026-01-12 00:04:00  377.6377  373.4863  374.0046
#
#       VL12/V    VL23/V    VL31/V     f/Hz  ...   IL3/A  PL1/kW  PL2/kW  \
# 2   651.0746  649.1744  649.1862  49.8500  ...  0.4565     0.0     0.0
# 6   650.7930  648.3517  648.7913  49.8927  ...  0.4649     0.0     0.0
# 10  651.2371  649.0068  648.9831  49.8734  ...  0.4505     0.0     0.0
# 14  651.6039  648.6692  648.6706  50.0066  ...  0.4271     0.0     0.0
# 18  651.7045  649.0541  649.0271  50.1304  ...  0.4626     0.0     0.0
#
#     PL3/kW  QL1/kvar  QL2/kvar  QL3/kvar   Vdc/V   Idc/A  Pdc/kW
# ...

# %%
stats_apu3.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 82462 entries, 2 to 338424
# Data columns (total 22 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Log Type    82462 non-null  str
#  1   System      82462 non-null  str
#  2   Time Stamp  82462 non-null  str
#  3   VL1N/V      82462 non-null  float64
#  4   VL2N/V      82462 non-null  float64
#  5   VL3N/V      82462 non-null  float64
#  6   VL12/V      82462 non-null  float64
#  7   VL23/V      82462 non-null  float64
#  8   VL31/V      82462 non-null  float64
#  9   f/Hz        82462 non-null  float64
#  10  IL1/A       82462 non-null  float64
#  11  IL2/A       82462 non-null  float64
#  12  IL3/A       82462 non-null  float64
#  13  PL1/kW      82462 non-null  float64
#  14  PL2/kW      82462 non-null  float64
#  15  PL3/kW      82462 non-null  float64
#  16  QL1/kvar    82462 non-null  float64
#  17  QL2/kvar    82462 non-null  float64
#  18  QL3/kvar    82462 non-null  float64
# ...

# %%
stats_apu3.describe()
# Out:
#              VL1N/V        VL2N/V        VL3N/V        VL12/V        VL23/V  \
# count  82462.000000  82462.000000  82462.000000  82462.000000  82462.000000
# mean     374.914488    373.663086    372.062780    649.567820    647.367062
# std        6.491258      6.945986      6.515008     11.353426     11.404484
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%      371.448825    369.016275    368.309050    642.262800    640.190275
# 50%      376.715850    375.363650    373.997250    653.096350    650.928900
# 75%      379.031150    378.007050    376.222075    656.762625    654.739825
# max      387.562700    390.409300    385.377200    673.743600    669.560000
#
#              VL31/V          f/Hz         IL1/A         IL2/A         IL3/A  \
# count  82462.000000  82462.000000  82462.000000  82462.000000  82462.000000
# mean     646.779314     50.106833    282.266636    280.381605    277.517594
# ...

# %%
apu3 = stats_apu3.copy()
# 1. Đảm bảo cột Time Stamp là kiểu datetime và đặt làm Index
apu3['Time Stamp'] = pd.to_datetime(apu3['Time Stamp'])
apu3.set_index('Time Stamp', inplace=True)

# 2. Sau đó mới chạy lại lệnh vẽ biểu đồ
cols_to_plot = ['VL1N/V']
apu3[cols_to_plot].resample('D').mean().plot(subplots=True, figsize=(16, 6), grid=True)
#plt.ylim(350,400)
plt.show()

# %%
cols_to_plot = ['VL3N/V']
apu3[cols_to_plot].resample('D').mean().plot(subplots=True, figsize=(16, 6), grid=True)
#plt.ylim(350,400)
plt.show()

# %%
cols_to_plot = ['VL23/V']
apu3[cols_to_plot].resample('D').mean().plot(subplots=True, figsize=(16, 6), grid=True)
#plt.ylim(350,400)
plt.show()

# %%
cols_to_plot = ['f/Hz']
apu3[cols_to_plot].resample('D').mean().plot(subplots=True, figsize=(16, 6), grid=True)
#plt.ylim(350,400)
plt.show()

# %%
cols_to_plot = ['IL1/A']
apu3[cols_to_plot].resample('D').mean().plot(subplots=True, figsize=(16, 6), grid=True)
#plt.ylim(350,400)
plt.show()

# %%
cols_to_plot = ['PL1/kW']
apu3[cols_to_plot].resample('D').mean().plot(subplots=True, figsize=(16, 6), grid=True)
#plt.ylim(350,400)
plt.show()

# %% [markdown]
# APU 3 xảy ra sự cố vào ngày 11/2, mất dữ liệu ngày 12, 13

# %% [markdown]
# Xem xét ngày 11/2

# %%
stats_s1302 = stats_apu3[stats_apu3['Time Stamp'].str.startswith('2026-02-13')]
s1302 = stats_s1302.copy()
# 1. Đảm bảo cột Time Stamp là kiểu datetime và đặt làm Index
s1302['Time Stamp'] = pd.to_datetime(s1302['Time Stamp'])
s1302.set_index('Time Stamp', inplace=True)

# 2. Sau đó mới chạy lại lệnh vẽ biểu đồ
cols_to_plot = ['VL1N/V']
s1302[cols_to_plot].plot(subplots=True, figsize=(16, 6), grid=True)
#plt.ylim(bottom=0)
plt.title("dữ liệu VL1N/V của APU 3 trong ngày 2026-02-13")
#plt.ylim(350,390)
plt.show()

# %%
stats_s1202 = stats_apu3[stats_apu3['Time Stamp'].str.startswith('2026-02-12')]
s1202 = stats_s1202.copy()
# 1. Đảm bảo cột Time Stamp là kiểu datetime và đặt làm Index
s1202['Time Stamp'] = pd.to_datetime(s1202['Time Stamp'])
s1202.set_index('Time Stamp', inplace=True)

# 2. Sau đó mới chạy lại lệnh vẽ biểu đồ
cols_to_plot = ['VL1N/V']
s1202[cols_to_plot].plot(subplots=True, figsize=(16, 6), grid=True)
#plt.ylim(bottom=0)
plt.title("dữ liệu VL1N/V của APU 3 trong ngày 2026-02-12")
#plt.ylim(350,390)
plt.show()

# %%
stats_s1102 = stats_apu3[stats_apu3['Time Stamp'].str.startswith('2026-02-11')]
s1102 = stats_s1102.copy()
# 1. Đảm bảo cột Time Stamp là kiểu datetime và đặt làm Index
s1102['Time Stamp'] = pd.to_datetime(s1102['Time Stamp'])
s1102.set_index('Time Stamp', inplace=True)

# 2. Sau đó mới chạy lại lệnh vẽ biểu đồ
cols_to_plot = ['VL1N/V']
s1102[cols_to_plot].plot(subplots=True, figsize=(16, 6), grid=True)
#plt.ylim(bottom=0)
plt.title("dữ liệu VL1N/V của APU 3 trong ngày 2026-02-11")
#plt.ylim(350,390)
plt.show()

# %% [markdown]
# Mất dữ liệu từ 12h trưa ngày 10/2 đến 15h25 ngày 11/2, sau đó mất dữ liệu từ 16h ngày 11/2 đến 14h ngày 13/2

# %%
stats_s1002 = stats_apu3[stats_apu3['Time Stamp'].str.startswith('2026-02-10')]
s1002 = stats_s1002.copy()
# 1. Đảm bảo cột Time Stamp là kiểu datetime và đặt làm Index
s1002['Time Stamp'] = pd.to_datetime(s1002['Time Stamp'])
s1002.set_index('Time Stamp', inplace=True)

# 2. Sau đó mới chạy lại lệnh vẽ biểu đồ
cols_to_plot = ['VL1N/V']
s1002[cols_to_plot].plot(subplots=True, figsize=(16, 6), grid=True)
#plt.ylim(bottom=0)
plt.title("dữ liệu VL1N/V của APU 3 trong ngày 2026-02-10")
#plt.ylim(350,390)
plt.show()

# %%
stats_s0902 = stats_apu3[stats_apu3['Time Stamp'].str.startswith('2026-02-09')]
s0902 = stats_s0902.copy()
# 1. Đảm bảo cột Time Stamp là kiểu datetime và đặt làm Index
s0902['Time Stamp'] = pd.to_datetime(s0902['Time Stamp'])
s0902.set_index('Time Stamp', inplace=True)

# 2. Sau đó mới chạy lại lệnh vẽ biểu đồ
cols_to_plot = ['VL1N/V']
s0902[cols_to_plot].plot(subplots=True, figsize=(16, 6), grid=True)
#plt.ylim(bottom=0)
plt.title("dữ liệu VL1N/V của APU 3 trong ngày 2026-02-09")
#plt.ylim(350,390)
plt.show()

# %%
cols_to_plot = ['VL2N/V']
s1002[cols_to_plot].plot(subplots=True, figsize=(16, 6), grid=True)
#plt.ylim(bottom=0)
plt.title("dữ liệu VL2N/V của APU 3 trong ngày 2026-02-10")
#plt.ylim(350,390)
plt.show()

# %%
cols_to_plot = ['VL12/V']
s1002[cols_to_plot].plot(subplots=True, figsize=(16, 6), grid=True)
#plt.ylim(bottom=0)
plt.title("dữ liệu VL12/V của APU 3 trong ngày 2026-02-10")
#plt.ylim(350,390)
plt.show()

# %%
cols_to_plot = ['VL31/V']
s1002[cols_to_plot].plot(subplots=True, figsize=(16, 6), grid=True)
#plt.ylim(bottom=0)
plt.title("dữ liệu VL31/V của APU 3 trong ngày 2026-02-10")
#plt.ylim(350,390)
plt.show()

# %%
cols_to_plot = ['IL1/A']
s1002[cols_to_plot].plot(subplots=True, figsize=(16, 6), grid=True)
#plt.ylim(bottom=0)
plt.title("dữ liệu IL1/A của APU 3 trong ngày 2026-02-10")
#plt.ylim(350,390)
plt.show()

# %%
cols_to_plot = ['IL1/A']
s1102[cols_to_plot].plot(subplots=True, figsize=(16, 6), grid=True)
#plt.ylim(bottom=0)
plt.title("dữ liệu IL1/A của APU 3 trong ngày 2026-02-11")
#plt.ylim(350,390)
plt.show()

# %%
cols_to_plot = ['IL1/A']
s0902[cols_to_plot].plot(subplots=True, figsize=(16, 6), grid=True)
#plt.ylim(bottom=0)
plt.title("dữ liệu IL1/A của APU 3 trong ngày 2026-02-09")
#plt.ylim(350,390)
plt.show()

# %%
cols_to_plot = ['IL1/A']
s1302[cols_to_plot].plot(subplots=True, figsize=(16, 6), grid=True)
#plt.ylim(bottom=0)
plt.title("dữ liệu IL1/A của APU 3 trong ngày 2026-02-13")
#plt.ylim(350,390)
plt.show()

# %% [markdown]
# ## Kết luận
# - APU 3 bị mất dữ liệu từ 12h ngày 10/2, 15h ngày 11/2 dữ liệu chập chờn và đến 14h ngày 13/2 mới hoạt động bình thường trở lại
