# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
stats = pd.read_csv(r'D:\energy\PV\analysis\APU_Stat_10s.csv');
stats.head()
# Out:
#        Log Type System           Time Stamp    VL1N/V    VL2N/V    VL3N/V  \
# 0  APU Stat 10s  APU 1  2026-01-12 00:00:00  375.1977  376.4349  373.0216
# 1  APU Stat 10s  APU 2  2026-01-12 00:00:00  375.1977  376.4349  373.0216
# 2  APU Stat 10s  APU 3  2026-01-12 00:00:00  376.5606  373.9651  372.8825
# 3  APU Stat 10s  APU 4  2026-01-12 00:00:00  376.5606  373.9651  372.8825
# 4  APU Stat 10s  APU 1  2026-01-12 00:01:00  375.1189  376.0260  372.9874
#
#      VL12/V    VL23/V    VL31/V     f/Hz  ...   IL3/A  PL1/kW  PL2/kW  PL3/kW  \
# 0  652.1350  648.5198  652.0514  49.8521  ...  0.5301     0.0     0.0     0.0
# 1  652.1350  648.5198  652.0514  49.8521  ...  0.4907     0.0     0.0     0.0
# 2  651.0746  649.1744  649.1862  49.8500  ...  0.4565     0.0     0.0     0.0
# 3  651.0746  649.1744  649.1862  49.8500  ...  0.5638     0.0     0.0     0.0
# 4  651.8266  647.7210  651.6465  49.8938  ...  0.5160     0.0     0.0     0.0
#
# ...

# %%
stats_apu2 = stats.loc[stats['System'] == 'APU 2']
stats_apu2.head()
# Out:
#         Log Type System           Time Stamp    VL1N/V    VL2N/V    VL3N/V  \
# 1   APU Stat 10s  APU 2  2026-01-12 00:00:00  375.1977  376.4349  373.0216
# 5   APU Stat 10s  APU 2  2026-01-12 00:01:00  375.1189  376.0260  372.9874
# 9   APU Stat 10s  APU 2  2026-01-12 00:02:00  374.6620  376.7216  372.9875
# 13  APU Stat 10s  APU 2  2026-01-12 00:03:00  375.4920  376.2658  373.2804
# 17  APU Stat 10s  APU 2  2026-01-12 00:04:00  376.1619  376.0987  374.3001
#
#       VL12/V    VL23/V    VL31/V     f/Hz  ...   IL3/A  PL1/kW  PL2/kW  \
# 1   652.1350  648.5198  652.0514  49.8521  ...  0.4907     0.0     0.0
# 5   651.8266  647.7210  651.6465  49.8938  ...  0.4907     0.0     0.0
# 9   652.2579  648.3894  651.8553  49.8754  ...  0.5067     0.0     0.0
# 13  652.6361  648.0391  651.5326  50.0089  ...  0.5003     0.0     0.0
# 17  652.7494  648.6435  652.1367  50.1280  ...  0.4971     0.0     0.0
#
#     PL3/kW  QL1/kvar  QL2/kvar  QL3/kvar   Vdc/V   Idc/A  Pdc/kW
# ...

# %% [markdown]
# Loc lay data cua apu 2

# %%
stats_apu2.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 86751 entries, 1 to 338423
# Data columns (total 22 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Log Type    86751 non-null  str
#  1   System      86751 non-null  str
#  2   Time Stamp  86751 non-null  str
#  3   VL1N/V      86751 non-null  float64
#  4   VL2N/V      86751 non-null  float64
#  5   VL3N/V      86751 non-null  float64
#  6   VL12/V      86751 non-null  float64
#  7   VL23/V      86751 non-null  float64
#  8   VL31/V      86751 non-null  float64
#  9   f/Hz        86751 non-null  float64
#  10  IL1/A       86751 non-null  float64
#  11  IL2/A       86751 non-null  float64
#  12  IL3/A       86751 non-null  float64
#  13  PL1/kW      86751 non-null  float64
#  14  PL2/kW      86751 non-null  float64
#  15  PL3/kW      86751 non-null  float64
#  16  QL1/kvar    86751 non-null  float64
#  17  QL2/kvar    86751 non-null  float64
#  18  QL3/kvar    86751 non-null  float64
# ...

# %%
stats_apu2.describe()
# Out:
#              VL1N/V        VL2N/V        VL3N/V        VL12/V        VL23/V  \
# count  86751.000000  86751.000000  86751.000000  86751.000000  86751.000000
# mean     375.435164    374.115527    372.807523    650.728187    646.558090
# std        6.012652      6.311221      6.058852     10.257681     10.584536
# min       61.509700     65.679400     69.052700    165.477200    118.409500
# 25%      371.587850    369.842800    368.737350    643.431200    638.802900
# 50%      376.898100    376.153700    374.791600    654.113000    650.186400
# 75%      379.428550    378.651100    376.964350    657.836050    654.050750
# max      390.946300    387.819100    386.465800    674.687100    668.989800
#
#              VL31/V          f/Hz         IL1/A         IL2/A         IL3/A  \
# count  86751.000000  86751.000000  86751.000000  86751.000000  86751.000000
# mean     650.848947     50.108873    276.937042    277.229385    278.409171
# ...

# %%
apu2 = stats_apu2.copy()
# 1. Đảm bảo cột Time Stamp là kiểu datetime và đặt làm Index
apu2['Time Stamp'] = pd.to_datetime(apu2['Time Stamp'])
apu2.set_index('Time Stamp', inplace=True)

# 2. Sau đó mới chạy lại lệnh vẽ biểu đồ
cols_to_plot = ['VL1N/V']
apu2[cols_to_plot].resample('D').mean().plot(subplots=True, figsize=(16, 6), grid=True)
#plt.ylim(350,400)
plt.show()

# %% [markdown]
# Du lieu thap bat thuong vao ngay 11/2, cac ngay con lai co ve bth, xem xet them ngay 6.7/3

# %%
cols_to_plot = ['VL2N/V']
apu2[cols_to_plot].resample('D').mean().plot(subplots=True, figsize=(16, 6), grid=True)
#plt.ylim(350,400)
plt.show()

# %% [markdown]
# Du lieu thap bat thuong vao 11/2 trung voi vl1, xem xet ngay 17,18/2 sao thap vay

# %%
cols_to_plot = ['VL3N/V']
apu2[cols_to_plot].resample('D').mean().plot(subplots=True, figsize=(16, 6), grid=True)
#plt.ylim(350,400)
plt.show()

# %% [markdown]
# ngay 11/2 kha bth, thấp nhất vào 17,18 /2
# Ngưỡng phát hiện < 370
# Giải thích lý do vì sao cả vl1,  vl2 đều thấp mà vl3 lại bth?

# %%
cols_to_plot = ['VL12/V']
apu2[cols_to_plot].resample('D').mean().plot(subplots=True, figsize=(16, 6), grid=True)
#plt.ylim(350,400)
plt.show()

# %% [markdown]
# Khá giống VL1N, thang đo khác nhau

# %%
cols_to_plot = ['VL23/V']
apu2[cols_to_plot].resample('D').mean().plot(subplots=True, figsize=(16, 6), grid=True)
#plt.ylim(350,400)
plt.show()

# %% [markdown]
# Gióng vl2

# %%
cols_to_plot = ['VL31/V']
apu2[cols_to_plot].resample('D').mean().plot(subplots=True, figsize=(16, 6), grid=True)
#plt.ylim(350,400)
plt.show()

# %% [markdown]
# giống vl2

# %%
cols_to_plot = ['f/Hz']
apu2[cols_to_plot].resample('D').mean().plot(subplots=True, figsize=(16, 6), grid=True)
#plt.ylim(350,400)
plt.show()

# %% [markdown]
# Tần số thấp nhất ngày 11/2

# %%
cols_to_plot = ['IL1/A']
apu2[cols_to_plot].resample('D').mean().plot(subplots=True, figsize=(16, 6), grid=True)
#plt.ylim(350,400)
plt.show()

# %% [markdown]
# Thấp nhất ngày 11/2, xem xét thêm ngày 26/2

# %%
cols_to_plot = ['IL2/A']
apu2[cols_to_plot].resample('D').mean().plot(subplots=True, figsize=(16, 6), grid=True)
#plt.ylim(350,400)
plt.show()

# %% [markdown]
# Giống IL1

# %%
cols_to_plot = ['IL3/A']
apu2[cols_to_plot].resample('D').mean().plot(subplots=True, figsize=(16, 6), grid=True)
#plt.ylim(350,400)
plt.show()

# %%
cols_to_plot = ['PL1/kW']
apu2[cols_to_plot].resample('D').mean().plot(subplots=True, figsize=(16, 6), grid=True)
#plt.ylim(350,400)
plt.show()

# %% [markdown]
# Thấp cùng ngày với I

# %%
cols_to_plot = ['PL3/kW']
apu2[cols_to_plot].resample('D').mean().plot(subplots=True, figsize=(16, 6), grid=True)
#plt.ylim(350,400)
plt.show()

# %%
cols_to_plot = ['QL1/kvar']
apu2[cols_to_plot].resample('D').mean().plot(subplots=True, figsize=(16, 6), grid=True)
#plt.ylim(350,400)
plt.show()

# %% [markdown]
# Thấp nhất ngày 17/02

# %%
cols_to_plot = ['QL3/kvar']
apu2[cols_to_plot].resample('D').mean().plot(subplots=True, figsize=(16, 6), grid=True)
#plt.ylim(350,400)
plt.show()

# %%
cols_to_plot = ['Vdc/V']
apu2[cols_to_plot].resample('D').mean().plot(subplots=True, figsize=(16, 6), grid=True)
#plt.ylim(350,400)
plt.show()

# %%
cols_to_plot = ['Idc/A']
apu2[cols_to_plot].resample('D').mean().plot(subplots=True, figsize=(16, 6), grid=True)
#plt.ylim(350,400)
plt.show()

# %%
cols_to_plot = ['Pdc/kW']
apu2[cols_to_plot].resample('D').mean().plot(subplots=True, figsize=(16, 6), grid=True)
#plt.ylim(350,400)
plt.show()

# %%
stats_s1102 = stats_apu2[stats_apu2['Time Stamp'].str.startswith('2026-02-11')]

# %%
stats_s1102.describe()
# Out:
#             VL1N/V       VL2N/V       VL3N/V       VL12/V       VL23/V  \
# count  1282.000000  1282.000000  1282.000000  1282.000000  1282.000000
# mean    376.418026   374.508811   374.965118   652.642449   649.061094
# std      10.478649    10.059878     9.926057    15.869902    17.193958
# min      61.509700    65.679400    69.052700   165.477200   118.409500
# 25%     374.915700   373.468275   374.696675   651.575850   647.981300
# 50%     376.037650   374.528450   375.556800   652.974000   649.418550
# 75%     379.504325   376.691225   376.429200   655.562700   652.100150
# max     383.760200   379.726900   379.664200   661.428600   657.592000
#
#             VL31/V         f/Hz        IL1/A        IL2/A        IL3/A  \
# count  1282.000000  1282.000000  1282.000000  1282.000000  1282.000000
# mean    652.783686    50.059413    55.007182    54.685782    54.861732
# std      16.890760     1.120970   114.192681   114.107004   114.398073
# ...

# %%
stats_s1102 = stats_apu2[stats_apu2['Time Stamp'].str.startswith('2026-02-11')]
s1102 = stats_s1102.copy()
# 1. Đảm bảo cột Time Stamp là kiểu datetime và đặt làm Index
s1102['Time Stamp'] = pd.to_datetime(s1102['Time Stamp'])
s1102.set_index('Time Stamp', inplace=True)

# 2. Sau đó mới chạy lại lệnh vẽ biểu đồ
cols_to_plot = ['VL1N/V']
s1102[cols_to_plot].plot(subplots=True, figsize=(16, 6), grid=True)
#plt.ylim(bottom=0)
plt.title("dữ liệu VL1N/V của APU 2 trong ngày 2026-02-11")
#plt.ylim(350,390)
plt.show()

# %%
cols_to_plot = ['VL3N/V']
s1102[cols_to_plot].plot(subplots=True, figsize=(16, 6), grid=True)
#plt.ylim(bottom=0)
plt.title("dữ liệu VL3N/V của APU 2 trong ngày 2026-02-11")
#plt.ylim(350,390)
plt.show()

# %%
cols_to_plot = ['f/Hz']
s1102[cols_to_plot].plot(subplots=True, figsize=(16, 6), grid=True)
#plt.ylim(bottom=0)
plt.title("dữ liệu f/Hz của APU 2 trong ngày 2026-02-11")
#plt.ylim(350,390)
plt.show()

# %%
cols_to_plot = ['PL1/kW']
s1102[cols_to_plot].plot(subplots=True, figsize=(16, 6), grid=True)
#plt.ylim(bottom=0)
plt.title("dữ liệu PL1/kW của APU 2 trong ngày 2026-02-11")
#plt.ylim(350,390)
plt.show()

# %%
stats_s1702 = stats_apu2[stats_apu2['Time Stamp'].str.startswith('2026-02-17')]
s1702 = stats_s1702.copy()
# 1. Đảm bảo cột Time Stamp là kiểu datetime và đặt làm Index
s1702['Time Stamp'] = pd.to_datetime(s1702['Time Stamp'])
s1702.set_index('Time Stamp', inplace=True)

# 2. Sau đó mới chạy lại lệnh vẽ biểu đồ
cols_to_plot = ['VL1N/V']
s1702[cols_to_plot].plot(subplots=True, figsize=(16, 6), grid=True)
#plt.ylim(bottom=0)
plt.title("dữ liệu VL1N/V của APU 2 trong ngày 2026-02-17")
plt.ylim(350,390)
plt.show()

# %%
cols_to_plot = ['VL3N/V']
s1702[cols_to_plot].plot(subplots=True, figsize=(16, 6), grid=True)
#plt.ylim(bottom=0)
plt.title("dữ liệu VL3N/V của APU 2 trong ngày 2026-02-17")
plt.ylim(350,390)
plt.show()

# %%
cols_to_plot = ['PL1/kW']
s1702[cols_to_plot].plot(subplots=True, figsize=(16, 6), grid=True)
#plt.ylim(bottom=0)
plt.title("dữ liệu PL1/kW của APU 2 trong ngày 2026-02-17")

plt.show()

# %%
stats_s1702.describe()
# Out:
#             VL1N/V       VL2N/V       VL3N/V       VL12/V       VL23/V  \
# count  1440.000000  1440.000000  1440.000000  1440.000000  1440.000000
# mean    374.753617   370.395293   369.770403   647.454053   641.491188
# std      10.744318    11.292630    11.164562    18.803617    19.313844
# min     358.623400   354.231700   353.785000   620.565700   615.364900
# 25%     362.858700   357.843175   357.370950   626.566075   619.917700
# 50%     380.981050   377.164650   376.309750   658.502500   653.267600
# 75%     383.999875   379.940925   379.245700   663.432500   657.877800
# max     389.938800   386.846400   385.523200   673.119200   667.961900
#
#             VL31/V         f/Hz        IL1/A        IL2/A        IL3/A  \
# count  1440.000000  1440.000000  1440.000000  1440.000000  1440.000000
# mean    646.086621    50.136627   209.873499   210.289703   210.510148
# std      18.662830     0.099750   242.088414   242.753191   243.009154
# ...

# %%
stats_s2602 = stats_apu2[stats_apu2['Time Stamp'].str.startswith('2026-02-26')]
s2602 = stats_s2602.copy()
# 1. Đảm bảo cột Time Stamp là kiểu datetime và đặt làm Index
s2602['Time Stamp'] = pd.to_datetime(s2602['Time Stamp'])
s2602.set_index('Time Stamp', inplace=True)

# 2. Sau đó mới chạy lại lệnh vẽ biểu đồ
cols_to_plot = ['VL1N/V']
s2602[cols_to_plot].plot(subplots=True, figsize=(16, 6), grid=True)
#plt.ylim(bottom=0)
plt.title("dữ liệu VL1N/V của APU 2 trong ngày 2026-02-26")
plt.ylim(350,390)
plt.show()

# %%
cols_to_plot = ['PL1/kW']
s2602[cols_to_plot].plot(subplots=True, figsize=(16, 6), grid=True)
#plt.ylim(bottom=0)
plt.title("dữ liệu PL1/kW của APU 2 trong ngày 2026-02-26")
#plt.ylim(350,390)
plt.show()

# %%
cols_to_plot = ['PL1/kW']
s1702[cols_to_plot].plot(subplots=True, figsize=(16, 6), grid=True)
#plt.ylim(bottom=0)
plt.title("dữ liệu PL1/kW của APU 2 trong ngày 2026-02-17")

plt.show()

# %%
stats_s1802 = stats_apu2[stats_apu2['Time Stamp'].str.startswith('2026-02-18')]
s1802 = stats_s1802.copy()
# 1. Đảm bảo cột Time Stamp là kiểu datetime và đặt làm Index
s1802['Time Stamp'] = pd.to_datetime(s1802['Time Stamp'])
s1802.set_index('Time Stamp', inplace=True)

# 2. Sau đó mới chạy lại lệnh vẽ biểu đồ
cols_to_plot = ['PL1/kW']
s1702[cols_to_plot].plot(subplots=True, figsize=(16, 6), grid=True)
#plt.ylim(bottom=0)
plt.title("dữ liệu PL1N/kW của APU 2 trong ngày 2026-02-18")
#plt.ylim(350,390)
plt.show()

# %% [markdown]
# ## Kết luận
# - APU 2 có thấp bất thường vào ngày 11/2 tất cả thông số đều bất thường
# - VL3N có trung bình thấp nhất vào ngày 17/2
# - Vào ngày 26/2, thông số về PL, IL, P, I đều thấp hơn ngày bình thường
# Giải thích
